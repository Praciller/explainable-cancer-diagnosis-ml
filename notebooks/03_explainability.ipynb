# %% [markdown]
# # Explainability
# Generate global importance and SHAP outputs from the persisted best model.

# %%
from src.explainability.explain_model import explain_best_model
explain_best_model(max_shap_samples=100)
print('Saved explainability figures and summary.')
