# %% [markdown]
# # Model Experiments
# Training remains in reusable Python modules.

# %%
from src.models.train_baseline import train_baseline_models
result = train_baseline_models(seed=42, mlflow_enabled=False)
result.best_model_name, result.metrics

# %%
from src.evaluation.evaluate_models import evaluate_models
evaluate_models()
