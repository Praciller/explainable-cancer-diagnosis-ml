# %% [markdown]
# # Exploratory Data Analysis
# This notebook calls production modules and does not duplicate pipeline logic.

# %%
from src.data.load_dataset import load_dataset_frame
from src.evaluation.generate_eda import generate_eda
bundle = load_dataset_frame()
bundle.frame.shape, bundle.frame['label'].value_counts()

# %%
bundle.features.describe().T

# %%
generate_eda()
print('Saved EDA summary and three required figures.')
